# %%
value=10
print("value:",value)
print("correct")
# Out:
# value: 10
# correct

# %%
password="hope@123"
num=(input("enter a password:"))
if num==password:
    print("password correct")
else:
    print("password wrong")
# Out:
# enter a password: hope
# password wrong

# %%
age=20
print("adults")
# Out:
# adults

# %%
age=20
print("age:",age)
if age<30:
     print("adults")
# Out:
# age: 20
# adults

# %%
num=int(input("enter a number:"))
if num<2:
        print("no is positive")
else:
        print("no is negative")
# Out:
# enter a number: 1
# no is positive

# %%
num=int(input("enter a number to check:"))
if num%5:
    print
